# %%
# prompt: write all the above code here

# Python
# Libraries->Numpy,Pandas,Mathplot,Seaborn,

# SQL->Data analysis in mysql

# Excel->Cleaning,Transforming,visualization

#PowerBi

#projects

user_input = input("Enter your input")
try:
  value = int(user_input)
  print(f"You entered an integer: {value}")
except ValueError:
  print("Invalid input. Please enter an integer.")

try:
  value = float(user_input)
  print(f"You entered a float: {value}") #Corrected the message
except ValueError:
  print("Invalid input. Please enter a float.") #Corrected the message

try:
  value = user_input
  print(f"You entered a string: {value}") #Corrected the message and type
except ValueError:
  print("This shouldn't print for string input.") #Corrected the message

#eval function
exp = eval(input("enter the input"))
print(exp)
print(type(exp))
# Type casting
a = 123
b = 1.23
print(type(a))
print(type(b))
c = float(a)
d = int(b)
print(type(c))
print(type(d))

e = a+b
print(e)
print(type(e))
# problem solving
print("Abhishek \n 24 \n Saharanpur")
# swap of two number
a = 10
b=20
c= a
a=b
b=c
print(a)
print(b)
x = 12.5
print(type(int(x)))
student_details = input("enter the student details")
name,roll_number,department = student_details.split(",")
print(name)
print(roll_number)
print(department)
print(not(3>4 and 5>6))
a = 10
b = 8
print(a^b)
print(10>>2)
print(10>>1)
print(10<<1)
print(10<<2)
a = "hello"
print("l" in a)
print(a.upper())
marks = int(input("enter the marks"))
if(marks>=90):
  print("A")
elif(marks>=80):
  print("B")
elif(marks>=70):
  print("C")
elif(marks>=60):
  print("D")
else:
  print("E")

marks = int(input("enter the marks"))
grade = "A" if marks >= 90 else "B" if marks >= 80 else "C" if marks >= 70 else "D" if marks >= 60 else "E"
print(grade) #Added print statement
# Out:
# new data analysis branch

# %%
print(3>4 or 5>6)
# Out:
# False
